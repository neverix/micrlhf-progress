# %%
# %load_ext autoreload
# %autoreload 2
import penzai
from penzai import pz
pz.ts.register_as_default()
pz.ts.register_autovisualize_magic()
pz.enable_interactive_context()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.llama import main
main()
# Out:
# /home/neverix/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.12/lib/python3.12/site-packages/jax/_src/dtypes.py:310: RuntimeWarning: overflow encountered in cast
#   return np.asarray(x, dtype)
# /home/neverix/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.12/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:2181: RuntimeWarning: overflow encountered in cast
#   out = np.asarray(object, dtype=dtype)
# ...
