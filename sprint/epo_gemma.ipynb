# %%
import os
if "models" not in os.listdir("."):
    os.chdir("..")

# %%
# %load_ext autoreload
# %autoreload 2
import penzai
from penzai import pz
pz.ts.register_as_default()
pz.ts.register_autovisualize_magic()
pz.enable_interactive_context()

# %%
# from micrlhf.utils.load_sae import get_sae
# import jax.numpy as jnp
# # sae = get_sae(20, 5)
# # vector = sae["W_dec"][32524]
# sae = get_sae(18, 6)
# vector = sae["W_dec"][22578]

# %%
from micrlhf.llama import LlamaTransformer
from transformers import AutoTokenizer


filename = "models/gemma-2b-it.gguf"
llama = LlamaTransformer.from_pretrained(filename, device_map="auto", from_type="gemma", load_eager=True)
tokenizer = AutoTokenizer.from_pretrained("NousResearch/gemma-2b-it-tokenizer")
tokenizer.padding_side = "right"

# %%
import numpy as np
from matplotlib import pyplot as plt
from micrlhf.sampling import sample, LlamaKVCachingTransformer
from micrlhf.utils.activation_manipulation import replace_activation, add_vector
import jax.numpy as jnp


def self_explain(vector, bs=128, msl=48, prompt="<|user|>\nWhat is the meaning of the word \"X\"?<|end|>\n<|assistant|>\nThe meaning of the word \"X\" is \""):
    scales = np.linspace(0, 200, bs)
    act_rep = replace_activation(llama, vector[None, :] * jnp.asarray(scales)[:, None], prompt=prompt, tokenizer=tokenizer)
    act_rep = LlamaKVCachingTransformer.from_uncached(act_rep, cache_len=msl, batch_axes={"batch": bs})
    texts = sample(act_rep, tokenizer, prompt, batch_size=bs, do_sample=True, max_seq_len=msl, verbose=False)[0]
    return list(zip(scales, texts))

# %%
from micrlhf.utils.load_sae import get_sae
from micrlhf.utils.vector_storage import save_and_upload_vector, download_vector
import jax.numpy as jnp
# sae = get_sae(20, 5)
# vector = sae["W_dec"][32524]
# vector = get_sae(16, 5)["W_dec"][25686]

# dictionary = get_sae(20, 6)["W_dec"]

# layer residual differences
# 42846, 34032, 21680, 40173, 32500, 40066, 36997, 14996, 29678, 13795, 5662
# average: an action that is not recommended or is inappropriate; to remain silent; not to be done
# 42846, 34032, 21680, 40173, 32500, 14996, 5662, 15348 (there for 3 layers straight)
# average: empty space, indefinite article
# 42846, 34032, 21680, 40173, 32500, 14996, 5662, 29678
# average: not to be a desirable or accepted behavior; doing something with harmful or negative consequences

# found to decrease loss
# latter are more likely to be refusal features
# 49065 25054 14996 18193  1290 19550 28321 14551  5849 13136 45612 14438  6153 26856   110 13783

# 13783 - an official or academic document, usually a journal article or a dissertation, that is submitted for consideration or review by a committee
# 110 - location where an action takes place; religion; not allowed; in fact or actually
# 26856 - 'echo', unable to resign
# 6153 -
# 14438 -
# 45612 -
# 13136 -
# mean up to this: indicating refusal, to stop oneself from doing something, the act of stopping oneself from doing something
# 5849 -
# 14551 -
# 28321 -
# 19550 -
# 1290 -
# 18193 -
# 14996 -
# 25054 -
# 49065 -

# vector = dictionary[jnp.array([13783, 110, 26856, 6153, 14438, 45612, 13136])].mean(0)
# vector = dictionary[jnp.array([42846, 34032, 21680, 40173, 32500, 14996, 5662, 29678])].mean(0)
# def save(features, name):
#     vector = dictionary[jnp.array(features)].mean(0)
#     vector = vector / jnp.linalg.norm(vector)
#     save_and_upload_vector(f"phi-refusal-{name}", vector, overwrite=True)
    
# save([42846, 34032, 21680, 40173, 32500, 14996, 5662, 29678], "residual-commons")
# save([13783, 110, 26856, 6153, 14438, 45612, 13136], "picks-avg")
# save([13783, 110, 26856, 6153, 14438, 45612, 13136, 5849, 14551, 28321, 19550, 1290, 18193, 14996, 25054, 49065], "pics-avg-all")
vector = download_vector("gemma-refusal-l12", overwrite=True)

# %%
from micrlhf.llama import LlamaBlock
from micrlhf.flash import flashify
from micrlhf.sampling import sample, trange, jnp, load_tokenizer, jit_wrapper
get_resids = llama.select().at_instances_of(LlamaBlock).apply_with_selected_index(lambda i, x:
    pz.nn.Sequential([
        pz.de.TellIntermediate.from_config(tag=f"resid_pre.{i}"),
        x
    ])
)
get_resids = pz.de.CollectingSideOutputs.handling(get_resids, tag_predicate=lambda x: x.startswith("resid_pre"))
get_resids_call = jit_wrapper.Jitted(get_resids)
def rep_w_linear(mod):
    val = mod.table.embeddings.value  # vocabulary, embedding
    return pz.nn.Linear(pz.nn.Parameter(val, "input_embed"), ["vocabulary"], ["embedding"])
get_resids_one_hot = get_resids.select().at_instances_of(pz.nn.EmbeddingLookup).apply(rep_w_linear)
get_resids_one_hot_call = jit_wrapper.Jitted(get_resids_one_hot)

# %%
from micrlhf.sampling import sample, trange, jnp, load_tokenizer, jit_wrapper
from tqdm.auto import trange
from penzai.toolshed import sharding_util
import dataclasses
from functools import partial
import numpy as np
import jax

@jax.jit
def loss_fn(logits, inputs):
    losses = pz.nx.nmap(lambda l, i: jnp.take_along_axis(jax.nn.log_softmax(l[:-1], -1), i[1:, None], 1)[:, 0].mean()
                        )(logits.untag("seq", "vocabulary"), inputs.tokens.untag("seq"))
    return -losses

bs_start = llama.mesh.shape["dp"]
# n_x = 16
# n_x = 19
# n_x = 20
n_x = 31
tokens_init = tokenizer.encode(f"<start_of_turn>user\nX{' X' * (n_x - 1)}<end_of_turn>\n<start_of_turn>model\n")
optim_mask = ["X" in tokenizer.decode([token]) for token in tokens_init]
assert sum(optim_mask) == n_x
tokens_init = np.asarray(tokens_init)
MAX_ELITES = 4
PROB_SWAP = 0.1  # probability of a swap
PROB_GRADS = 0.8    # probability of using gradients 
tokens_init = np.repeat(tokens_init[None, :], MAX_ELITES, axis=0)
def tokens_to_array(tokens):
    token_array = jnp.asarray(tokens)
    if len(token_array) >= bs_start:
        token_array = jax.device_put(token_array, jax.sharding.NamedSharding(llama.mesh, jax.sharding.PartitionSpec("dp", "sp")))
    token_array = pz.nx.wrap(token_array, "batch", "seq")
    return token_array
def run_tokens(token_array, grad_metric=None):
    if not isinstance(token_array, pz.nx.NamedArray):
        token_array = tokens_to_array(token_array)
    inputs = llama.inputs.from_basic_segments(token_array)
    if grad_metric:
        @partial(jax.grad, has_aux=True)
        def lwg(x):
            logits, resids = get_resids_one_hot_call(dataclasses.replace(inputs, tokens=x))
            resids = {resid.tag: resid.value for resid in resids}
            metric = grad_metric(logits, resids, inputs)
            return metric, (logits, resids)
        vocab = llama.select().at_instances_of(pz.nn.EmbeddingLookup).get_sequence()[0].table.embeddings.value.named_shape["vocabulary"]
        one_hots = pz.nx.nmap(lambda x: jax.nn.one_hot(x, vocab))(inputs.tokens).tag("vocabulary")
        grad, (logits, resids) = lwg(one_hots)
    else:
        logits, resids = get_resids_call(inputs)
    losses = loss_fn(logits, inputs)
    if not grad_metric:
        resids = {resid.tag: resid.value for resid in resids}
    return_vals = logits, losses, resids
    if grad_metric:
        return_vals = return_vals + (grad,)
    return return_vals

mask = jax.device_put(jnp.asarray(optim_mask), jax.sharding.NamedSharding(llama.mesh, jax.sharding.PartitionSpec("sp")))

# @partial(jax.jit, static_argnames=("max_inv_temp", "expected_changes"))
@jax.jit
def temper(logits, key, elites, grads, max_inv_temp, expected_changes):
    key_choice, key_random = jax.random.split(key)
    index = jax.random.randint(key_choice, (), 0, len(logits) - 1)
    key_categorical, key_uniform, key_bernoulli, key_randint, key_use_grads, key_mutations = jax.random.split(key_random, 6)
    logit = logits[index]
    elite = elites[index]
    grads = grads[index]
    
    logit = jnp.roll(logit, 1, 0)
    logit = logit * jax.random.uniform(key_uniform, minval=0, maxval=max_inv_temp)
    use_grads = jax.random.bernoulli(key_use_grads, p=PROB_GRADS).astype(jnp.int_)
    logit = jax.lax.switch(use_grads, ((lambda x: x), (lambda x: jnp.where(grads, x, -jnp.inf))), logit)
    # print(expected_changes - 1)
    # print(jnp.maximum)
    to_change = jax.random.bernoulli(key_bernoulli, jnp.maximum(.5, expected_changes - 1) / mask.sum(), mask.shape)
    definite_indices = jax.random.randint(key_randint, mask.shape[:-1], 0, mask.shape[-1])
    definite_mask = jax.nn.one_hot(definite_indices, to_change.shape[-1], dtype=jnp.bool_)
    to_change = to_change | definite_mask
    changed = jnp.where(mask & to_change,
                        jax.random.categorical(key_categorical, logit),
                        elite)
    
    key_swap, key_mutations = jax.random.split(key_mutations)
    swap_indices = jax.random.randint(key_swap, (2,), 0, mask.sum())
    swap_from, swap_to = jnp.nonzero(mask, size=len(mask))[0][swap_indices]
    key_swap, key_mutations = jax.random.split(key_mutations)
    do_swap = jax.random.bernoulli(key_swap, p=PROB_SWAP)
    swapped = changed.at[swap_from].set(changed[swap_to]).at[swap_to].set(changed[swap_from])
    changed = jax.lax.cond(do_swap, lambda x: swapped, lambda x: x, changed)
    
    # key_delete, key_mutations = jax.random.split(key_mutations)
    # delete_index = jax.random.randint(key_delete, (), 0, mask.sum())
    # indices = jnp.cumsum(mask)
    # indices_base = jnp.arange(len(changed))
    # deleted = jnp.where(mask, jnp.where(indices > delete_index, indices_base + 1, indices_base), changed)
    # key_delete, key_mutations = jax.random.split(key_mutations)
    # do_delete = jax.random.bernoulli(key_delete, p=0.1)
    # changed = jax.lax.cond(do_delete, lambda x: deleted, lambda x: x, changed)
    
    return changed

# @partial(jax.jit, static_argnames=("key", "candidates", "expected_changes"))
def algo_iteration(elites, vector, key="resid_pre.16", candidates=128, seed=13, expected_changes=1.5, max_inv_temp=2, topk=128):
    elites = elites.untag("solutions").tag("batch")
    logits, _, _, grads = run_tokens(elites, grad_metric=lambda _l, r, _i: (r[key][{"seq": -1}].untag("embedding") * vector).sum().data_array.mean())
    grads = pz.nx.nmap(lambda x: x >= jax.lax.top_k(x, topk)[0][-1])(grads.untag("vocabulary")).tag("vocabulary")
    logits = logits.untag("batch").tag("elites")

    tempered_samples = pz.nx.nmap(temper)(
        logits.untag("elites", "seq", "vocabulary"),
        pz.nx.wrap(jax.random.split(jax.random.key(seed), candidates), "batch"),
        elites.untag("batch", "seq"),
        grads.untag("batch", "seq", "vocabulary"),
        pz.nx.wrap(jnp.array(max_inv_temp)), pz.nx.wrap(jnp.array(expected_changes))).tag("seq")
    # tempered_samples = sharding_util.name_to_name_device_put(tempered_samples, llama.mesh, dict(batch="dp", seq="sp"))
    _, new_losses, new_resids = run_tokens(tempered_samples)

    new_scores = (new_resids[key][{"seq": -1}].untag("embedding") * vector).sum().astype(new_losses.dtype)
    metrics = pz.nx.nmap(lambda *xs: jnp.stack(xs))(new_losses, new_scores).tag("metrics")
    solution_axes = [k for k in tempered_samples.named_shape.keys() if k != "seq"]
    solutions = tempered_samples.untag(*solution_axes).flatten().tag("solutions").unwrap("solutions", "seq")
    metrics = metrics.untag(*(k for k in solution_axes if k != "seq")).flatten().tag("solutions").unwrap("solutions", "metrics")

    return solutions, metrics

# %%
import random


seed = random.randint(0, 2**32-1)
print("Seed:", seed)
np.random.seed(seed)
toks_init = tokens_init.copy()
toks_init[:, optim_mask] = np.random.randint(100, tokenizer.vocab_size, toks_init[:, optim_mask].shape)
best_metrics = None
best = tokens_to_array(toks_init).untag("batch").tag("solutions")
xent_min = 2
xent_max = 30
weights = jnp.stack((
    -jnp.exp(jnp.linspace(jnp.log(xent_min), jnp.log(xent_max), MAX_ELITES))[::-1],
    jnp.ones(MAX_ELITES),
), -1)
@partial(jax.jit, donate_argnums=(0, 1))
def combine_solutions(best_metrics, best, metrics, solutions):
    if best_metrics is not None:
        best_metrics = jnp.concatenate((best_metrics, metrics), 0)
        best = pz.nx.nmap(lambda a, b: jnp.concatenate((a, b)))(
            best.untag("solutions"),
            pz.nx.wrap(solutions, "solutions", "seq").untag("solutions")
        ).tag("solutions").unwrap("solutions", "seq")
    else:
        best_metrics = metrics
        best = solutions
    elite_mask = (best_metrics[None, :] * weights[:, None]).sum(-1).argmax(1)
    best_metrics = best_metrics[elite_mask]
    best = pz.nx.wrap(best[elite_mask], "solutions", "seq")
    return best_metrics, best
for seed in (bar := trange(2_500)):
    solutions, metrics = algo_iteration(best, vector, seed=seed)
    best_metrics, best = combine_solutions(best_metrics, best, metrics, solutions)
    m = {}
    for index in range(MAX_ELITES):
        i = index
        m |= {f"decoded.{i}": tokenizer.decode(best[{"solutions": index}].unwrap("seq")),
              f"loss.{i}": best_metrics[index][0], f"score.{i}": best_metrics[index][1]}
    bar.set_postfix(**m)
# Out:
# Seed: 1715734579
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f5fcc5cb850>>
# Traceback (most recent call last):
#   File "/home/neverix/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 33
#      31     return best_metrics, best
#      32 for seed in (bar := trange(2_500)):
# ---> 33     solutions, metrics = algo_iteration(best, vector, seed=seed)
#      34     best_metrics, best = combine_solutions(best_metrics, best, metrics, solutions)
#      35     m = {}
#
# Cell In[8], line 106, in algo_iteration(elites, vector, key, candidates, seed, expected_changes, max_inv_temp, topk)
#     104 def algo_iteration(elites, vector, key="resid_pre.16", candidates=128, seed=13, expected_changes=1.5, max_inv_temp=2, topk=128):
#     105     elites = elites.untag("solutions").tag("batch")
# --> 106     logits, _, _, grads = run_tokens(elites, grad_metric=lambda _l, r, _i: (r[key][{"seq": -1}].untag("embedding") * vector).sum().data_array.mean())
#     107     grads = pz.nx.nmap(lambda x: x >= jax.lax.top_k(x, topk)[0][-1])(grads.untag("vocabulary")).tag("vocabulary")
#     108     logits = logits.untag("batch").tag("elites")
#
# Cell In[8], line 47, in run_tokens(token_array, grad_metric)
#      45     vocab = llama.select().at_instances_of(pz.nn.EmbeddingLookup).get_sequence()[0].table.embeddings.value.named_shape["vocabulary"]
#      46     one_hots = pz.nx.nmap(lambda x: jax.nn.one_hot(x, vocab))(inputs.tokens).tag("vocabulary")
# ---> 47     grad, (logits, resids) = lwg(one_hots)
#      48 else:
#      49     logits, resids = get_resids_call(inputs)
#
#     [... skipping hidden 1 frame]
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/api.py:637, in grad.<locals>.grad_f_aux(*args, **kwargs)
#     634 @wraps(fun, docstr=docstr, argnums=argnums)
#     635 @api_boundary
#     636 def grad_f_aux(*args, **kwargs):
# --> 637   (_, aux), g = value_and_grad_f(*args, **kwargs)
#     638   return g, aux
#
#     [... skipping hidden 1 frame]
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/api.py:707, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     705 _check_scalar(ans)
#     706 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 707 g = vjp_py(lax_internal._one(ans))
#     708 g = g[0] if isinstance(argnums, int) else g
#     709 if not has_aux:
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/tree_util.py:476, in _HashableCallableShim.__call__(self, *args, **kw)
#     475 def __call__(self, *args, **kw):
# --> 476   return self.fun(*args, **kw)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/api.py:2119, in _vjp_pullback_wrapper(name, out_primal_avals, io_tree, fun, *py_args_)
#    2112   if (not core.typecompat(ct_aval, ct_aval_expected) and
#    2113       not _temporary_dtype_exception(ct_aval, ct_aval_expected)):
#    2114     raise ValueError(
#    2115         "unexpected JAX type (e.g. shape/dtype) for argument to vjp function: "
#    2116         f"got {ct_aval.str_short()}, but expected {ct_aval_expected.str_short()} "
#    2117         f"because the corresponding output of the function {name} had JAX type "
#    2118         f"{aval.str_short()}")
# -> 2119 ans = fun(*args)
#    2120 return tree_unflatten(out_tree, ans)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/tree_util.py:476, in _HashableCallableShim.__call__(self, *args, **kw)
#     475 def __call__(self, *args, **kw):
# --> 476   return self.fun(*args, **kw)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:150, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     148 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     149 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 150 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     151 return map(instantiate_zeros, arg_cts)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:250, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     247   cts_out = get_primitive_transpose(eqn.primitive)(
#     248       params, call_jaxpr, invals, cts_in, cts_in_avals)
#     249 elif eqn.primitive in reducing_transposes:
# --> 250   cts_out = reducing_transposes[eqn.primitive](
#     251       cts_in, *invals, **eqn.params)
#     252 else:
#     253   cts_out = get_primitive_transpose(eqn.primitive)(
#     254       cts_in, *invals, **eqn.params)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/pjit.py:2294, in _pjit_transpose(cts_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *primals_in)
#    2291   transpose_in_layouts = (None,) * len(attrs_tracked) + transpose_in_layouts
#    2292   transpose_out_layouts = (None,) * len(attrs_tracked) + transpose_out_layouts
# -> 2294 nz_cts_out = pjit_p.bind(
#    2295     *primals_and_nz_cts_in,
#    2296     jaxpr=transpose_jaxpr,
#    2297     in_shardings=transpose_in_shardings,
#    2298     out_shardings=transpose_out_shardings,
#    2299     in_layouts=transpose_in_layouts,
#    2300     out_layouts=transpose_out_layouts,
#    2301     resource_env=resource_env,
#    2302     donated_invars=(False,) * len(primals_and_nz_cts_in),
#    2303     name=name,
#    2304     keep_unused=keep_unused,
#    2305     inline=inline)
#    2307 if attrs_tracked:
#    2308   final_states, nz_cts_out = split_list(nz_cts_out, [len(init_states)])
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/core.py:2739, in AxisPrimitive.bind(self, *args, **params)
#    2735 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2736                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2737 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2738              else axis_main.with_cur_sublevel())
# -> 2739 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/core.py:433, in Primitive.bind_with_trace(self, trace, args, params)
#     431 def bind_with_trace(self, trace, args, params):
#     432   with pop_level(trace.level):
# --> 433     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     434   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/core.py:939, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     937   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     938 else:
# --> 939   return primitive.impl(*tracers, **params)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/pjit.py:1730, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1727 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1728 has_explicit_sharding = _pjit_explicit_sharding(
#    1729     in_shardings, out_shardings, None, None)
# -> 1730 return xc._xla.pjit(
#    1731     name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1732     tree_util.dispatch_registry,
#    1733     lambda x, sharding: pxla.shard_args([sharding], [x])[0],
#    1734     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/pjit.py:1733, in _pjit_call_impl.<locals>.<lambda>(x, sharding)
#    1727 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1728 has_explicit_sharding = _pjit_explicit_sharding(
#    1729     in_shardings, out_shardings, None, None)
#    1730 return xc._xla.pjit(
#    1731     name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1732     tree_util.dispatch_registry,
# -> 1733     lambda x, sharding: pxla.shard_args([sharding], [x])[0],
#    1734     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:116, in shard_args(shardings, args, canonicalize)
#     114   if canonicalize:
#     115     arg = xla.canonicalize_dtype(arg)
# --> 116   return shard_arg_handlers[type(arg)]([arg], shardings)
#     118 # type(arg) -> (indices, args, shardings)
#     119 batches = collections.defaultdict(lambda: ([], [], []))  # type: ignore
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/array.py:1137, in _array_shard_arg(xs, shardings)
#    1135 # Resharding starts here:
#    1136 elif dispatch.is_single_device_sharding(x.sharding):
# -> 1137   results.append(shard_device_array(x, devices, indices, sharding))
#    1138 else:
#    1139   results.append(
#    1140       shard_sharded_device_array_slow_path(x, devices, indices, sharding))
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/array.py:1074, in shard_device_array(x, devices, indices, sharding)
#    1072   shards = x._multi_slice(start_indices, limit_indices, removed_dims)
#    1073 aval = api_util.shaped_abstractify(x)
# -> 1074 return pxla.batched_device_put(aval, sharding, shards, devices)
#
# File ~/.cache/pypoetry/virtualenvs/micrlhf-progress-a058ydGG-py3.10/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:192, in batched_device_put(aval, sharding, xs, devices, committed)
#     189 if len(bufs) == len(xs):
#     190   return array.ArrayImpl(
#     191       aval, sharding, bufs, committed=committed, _skip_checks=True)
# --> 192 return xc.batched_device_put(aval, sharding, xs, list(devices), committed)
#
# KeyboardInterrupt:
